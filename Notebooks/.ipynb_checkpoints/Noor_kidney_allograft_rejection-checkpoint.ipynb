# %% [markdown]
# ## Installing package

# %%
#!pip install -e ../
#Note that you might need to restart the kernel after this step.

# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
# Out:
# scanpy==1.4.4.post1 anndata==0.6.22.post1 umap==0.3.10 numpy==1.17.4 scipy==1.3.2 pandas==0.25.3 scikit-learn==0.21.2 statsmodels==0.10.0

# %% [markdown]
# ## First, import your single cell data from a text file

# %%
#gzip -d is the same as gunzip, but works on Windows
# !gzip -d ../Kidney_allo_rejection_python_input.txt.gz
adata = sc.read_text(
    '../Kidney_allo_rejection_python_input.txt')  # the directory with the `.mtx` file
    # use gene symbols for the variable names (variables-axis index)
#Github cannot handle large files, so zipping compresses the large file.
# !gzip ../Kidney_allo_rejection_python_input.txt

# %% [markdown]
# #### Do not run unless for GSE dataset

# %%
import gzip
import shutil
with gzip.open('../GSE109564_Kidney.biopsy.dge.txt.gz', 'rb') as f_in:
    with open('../GSE109564_Kidney.biopsy.dge.txt', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
# Transporsing the text files in python
dataframe = pd.read_csv("../GSE109564_Kidney.biopsy.dge.txt",delimiter="\t")
dataframe = pd.DataFrame.transpose(dataframe)
dataframe.to_csv("Kidney.biopsy.dge.csv", encoding='utf-8', index=False)
# Starting analysis
adata = sc.read_csv(
    './Kidney.biopsy.dge.csv')  # the directory with the .mtx file
    # use gene symbols for the variable names (variables-axis index)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4487 × 20477

# %% [markdown]
# ## You can use scanpy to look at the top genes to make sure that your data has been imported correctly

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing by total count per cell
#     finished (0:00:01): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %% [markdown]
# ## Filtering cells and Normalization

# %%
from sc309 import scanpy_workflow

# %%
scanpy_workflow.filterRegress(adata)
# Out:
# normalizing by total count per cell
# Trying to set attribute `.obs` of view, making a copy.
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# regressing out ['n_counts', 'percent_mito']
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
#     finished (0:00:11)

# %%
scanpy_workflow.summarystatsplots(adata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3bde175908d3> in <module>
# ----> 1 scanpy_workflow.summarystatsplots(adata)
#
# c:\users\noor\documents\github\sc309\sc309\scanpy_workflow.py in summarystatsplots(SingleCellData)
#      38     sc.pl.scatter(SingleCellData, x='n_counts', y='n_genes') # Scatter plot between total counts and number of genes
#      39
# ---> 40     sc.pl.highly_variable_genes(SingleCellData) # Plotting highly variable genes (mean expression and dispersion)
#      41
#      42 def topclustergenes(SingleCellData):
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\plotting\_preprocessing.py in highly_variable_genes(adata_or_result, log, show, save, highly_variable_genes)
#      32         result = adata_or_result
#      33     if highly_variable_genes:
# ---> 34         gene_subset = result.highly_variable
#      35     else:
#      36         gene_subset = result.gene_subset
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'highly_variable'

# %% [markdown]
# ## PCA and UMAP

# %%
scanpy_workflow.topclustergenes(adata)
# Out:
# computing PCA with n_comps = 50
#     finished (0:00:06)
# computing neighbors
#     using 'X_pca' with n_pcs = 10
#     finished: added to `.uns['neighbors']`
#     'distances', distances for each pair of neighbors
#     'connectivities', weighted adjacency matrix (0:00:02)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:08)
# running Louvain clustering
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-f171a4b580f7> in <module>
# ----> 1 scanpy_workflow.topclustergenes(adata)
#
# c:\users\noor\documents\github\sc309\sc309\scanpy_workflow.py in topclustergenes(SingleCellData)
#      46
#      47     sc.tl.umap(SingleCellData) # Computing UMAP
# ---> 48     sc.tl.louvain(SingleCellData) ## Louvain clustering
#      49
#      50     sc.tl.rank_genes_groups(SingleCellData, 'louvain', method='wilcoxon') # Finding top genes for each cluster
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\tools\_louvain.py in louvain(adata, resolution, random_state, restrict_to, key_added, adjacency, flavor, directed, use_weights, partition_type, partition_kwargs, copy)
#     112             directed = False
#     113         if not directed: logg.debug('    using the undirected graph')
# --> 114         g = utils.get_igraph_from_adjacency(adjacency, directed=directed)
#     115         if use_weights:
#     116             weights = np.array(g.es["weight"]).astype(np.float64)
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\utils.py in get_igraph_from_adjacency(adjacency, directed)
#     379 def get_igraph_from_adjacency(adjacency, directed=None):
#     380     """Get igraph graph from adjacency matrix."""
# --> 381     import igraph as ig
#     382     sources, targets = adjacency.nonzero()
#     383     weights = adjacency[sources, targets]
#
# ModuleNotFoundError: No module named 'igraph'

# %% [markdown]
# ## Visualizing genes

# %%
scanpy_workflow.visualizegenes(adata)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-7912789b4b2f> in <module>
# ----> 1 scanpy_workflow.visualizegenes(adata)
#
# c:\users\noor\documents\github\sc309\sc309\scanpy_workflow.py in visualizegenes(SingleCellData)
#      54
#      55     sc.pl.pca_variance_ratio(SingleCellData, log=True) # Variance explained by PCs
# ---> 56     sc.pl.umap(SingleCellData, color=['louvain','NPHS1', 'NKG7', 'WT1', 'FCER1G', 'TYROBP', 'APOE', 'IL1B', 'CD3D', 'GZMA'], size = 50)
#      57     # Checking the expression of canonical genes for kidney and immune cells
#      58
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\plotting\_tools\scatterplots.py in umap(adata, **kwargs)
#     297     If `show==False` a :class:`~matplotlib.axes.Axes` or a list of it.
#     298     """
# --> 299     return plot_scatter(adata, 'umap', **kwargs)
#     300
#     301
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\plotting\_tools\scatterplots.py in plot_scatter(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, arrows, arrows_kwds, groups, components, layer, projection, color_map, palette, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     154             adata, value_to_plot, layer=layer,
#     155             groups=groups, palette=palette,
# --> 156             use_raw=use_raw, gene_symbols=gene_symbols,
#     157         )
#     158
#
# ~\AppData\Roaming\Python\Python37\site-packages\scanpy\plotting\_tools\scatterplots.py in _get_color_values(adata, value_to_plot, groups, palette, use_raw, gene_symbols, layer)
#     696         values = adata.raw.obs_vector(value_to_plot)
#     697     else:
# --> 698         values = adata.obs_vector(value_to_plot, layer=layer)
#     699
#     700     ###
#
# ~\AppData\Roaming\Python\Python37\site-packages\anndata\core\anndata.py in obs_vector(self, k, layer)
#    1480             return self.obs[k].values
#    1481         else:
# -> 1482             idx = self._normalize_indices((slice(None), k))
#    1483             a = self._get_X(layer=layer)[idx]
#    1484         if issparse(a):
#
# ~\AppData\Roaming\Python\Python37\site-packages\anndata\core\anndata.py in _normalize_indices(self, index)
#    1208         obs, var = unpack_index(index)
#    1209         obs = _normalize_index(obs, self.obs_names)
# -> 1210         var = _normalize_index(var, self.var_names)
#    1211         return obs, var
#    1212
#
# ~\AppData\Roaming\Python\Python37\site-packages\anndata\core\anndata.py in _normalize_index(index, names)
#     153         return slice(start, stop, step)
#     154     elif isinstance(index, (np.integer, int, str)):
# --> 155         return name_idx(index)
#     156     elif isinstance(index, (Sequence, np.ndarray, pd.Index)):
#     157         # here, we replaced the implementation based on name_idx with this
#
# ~\AppData\Roaming\Python\Python37\site-packages\anndata\core\anndata.py in name_idx(i)
#     140                 raise IndexError(
#     141                     'Key "{}" is not valid observation/variable name/index.'
# --> 142                     .format(i))
#     143             i = i_found[0]
#     144         return i
#
# IndexError: Key "louvain" is not valid observation/variable name/index.
